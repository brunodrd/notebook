# %% [markdown]
# <center>&nbsp;<br>
# <font size="12">Des fonctions récursives qui renvoient la liste des noeuds lors d'un parcours</font><br></center>
#
# ---
#
#
#
# ---

# %% [markdown]
# <center>&nbsp;<br>
# <font size="12">Première partie : sur feuille</font><br></center>
#
# ---
#
#
#
# ---

# %% [markdown]
# Voici un labyrinthe :
#
# <center>
#
#
# </center>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#
#
# *   l'entrée et la sortie sont marquées par un cercle plein dans un cercle vide.
# *   Les cercles pleins sont des cul de sac,
# *   Les carrés sont des intersections,
# *   Les cercles vides sont des noeuds sans intersection.

# %% [markdown]
# # <b><font color="#9356CA">DEFINITION :</b>
#
# Un **<font color="#9356CA">labyrinthe parfait**</font> est un labyrinthe dans lequel toutes les cases peuvent être atteintes, et cela avec un seul chemin possible.
#
# Un tel labyrinthe, peut donc être représenté par un arbre (son graphe ne comporte pas de cycles)
#
# **1.a Ce labyrinthe est il parfait ?**
#
#
# **1.b Pourquoi l'arbre correspondant est-il binaire ?**

# %% [markdown]
# **2. Faire la représentation de ce labyrinthe avec  un graphe (sur feuille).**
#
# Conventions utilisées :
#
# 1.   Les cases sont numérotées colones,ligne. Par exemple l'entrée est 04 et la sortie 44.
# 2.   Lorsqu'un noeud (une case) n'a qu'un fils, **on considérera que c'est un fils gauche,
#  même si on tourne à droite**
# 3.   De même, si à une intersection on peut aller tout droit ou à droite, on considèrera que tout droit est à gauche.

# %% [markdown]
# **3.  Quelle est la hauteur de l'arbre ?**

# %% [markdown]
# **4. Compréhension de l'arbre :**
#
# 4a. Dans ce labyrinthe, que peut-on dire des feuilles ?
#
# 4b. Et que dire d'un noeud ayant seulement un fils gauche ?

# %% [markdown]
# **5. Quelle est la profondeur du nœud (3,3) ? Qu'est-ce que cette profondeur représente dans notre problème ?**

# %% [markdown]
# **6. On donne ci-dessous l'image d'un labyrinthe différent.**
#
# Observez bien, il s'agit encore d'un labyrinthe parfait, qu'on pourra modéliser avec un arbre (graphe acyclique).
#
# Néanmoins dans ce second cas, l'arbre ne sera pas un arbre binaire, pouvez justifier cette affirmation ?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# &nbsp;<br>
# <center><font size="12">Deuxième  partie : utiliser un module pour créer une implémentation de cet arbre</font><br>
# </center>
#
# ---
#
#
#
# ---

# %% [markdown]
# <font color=lightseagreen size=6><b>Implémentation d'arbres avec 2 classes</b></font>
#
# Voici les fonctions de l'interface dont vous aurez besoin :
#
#
# ```
# # Notre arbre sera modélisé avec un dictionnaire.
# arbre = Arbre(etiquette) :
#     Crée un objet arbre, dont la racine porte l'étiquette passée en paramètre
#     Attributs :
#         arbre.noeuds : dictionnaire dont les clés sont les etiquettes des sommets et les valeurs les objets noeuds associés
#         arbre.etiquette_racine : etiquette de la racine de l'arbre
#
# ############### Primitives d'accès  ###############
#
# arbre.empty():
#     return True si Arbre est un arbre vide, False sinon
#
# arbre.filsD(etiquette) :
#     renvoie True si le noeud dont l'etiquette est donnée en paramètre à un fils droit, False sinon.
#
# arbre.filsG(etiquette) :
#     renvoie True si le noeud dont l'etiquette est donnée en paramètre à un fils droit, False sinon.
#
# arbre.racine() :
#     renvoie l'objet noeud de la racine
#         Les objets Noeuds disposent de 3 attributs :
#             fg et fd : objets Noeud fils gauche et droit
#             val : etiquette du noeud fils
#
# ############### Primitives d'ajouts ###############
#
# arbre.addG(etiquette_parent, etiquette_fils) -> None :
#     :param etiquette_parent: est une etiquette d'un noeud de l'arbre
#     :param etiquette_fils: est l'etiquette du fils gauche à ajouter
#
#     addG ajoute un fils gauche au noeud parent
#
#
#
# arbre.addD(etiquette_parent, etiquette_fils) -> None :
#     :param etiquette_parent: est une etiquette d'un noeud de l'arbre
#     :param etiquette_fils: est l'etiquette du fils droit à ajouter
#
#     addD ajoute un fils droit au noeud parent
#
#
# ############### Primitives d'extraction de sous arbres ###############
#
# arbre.sad(etiquette=None):
#     si le paramètre cle est absent, la méthode renvoie le SAD de la racine
#     si une etiquette et mentionnée, la méthode renvoie le SAD du noeud portant cette etiquette
#
# arbre.sag(etiquette=None):
#     si le paramètre cle est absent, la méthode renvoie le SAG de la racine
#     si une etiquette et mentionnée, la méthode renvoie le SAG du noeud portant cette etiquette
#
# ############### Primitive de représentation ###############
#
# print(arbre) : permet d'afficher l'arbre en mode texte
#
# arbre.show(etiquette=None,chemin = None):
#     Dessin de l'arbre.
#     Si etiquette est None, la fonction dessinne l'arbre complet
#     Sinon elle dessine le sous arbre dont la racine est etiquette
#     Le paramètre chemin peut$etre ajouté :c'est une liste d'étiquette. Tous les noeuds de cette liste seront représentés en vert.
# ```

# %% [markdown]
# Vous devez importer le fichier [module_tree.py](https://drive.google.com/file/d/1hJzgzJ8tZ8YQsypbmoh63Wibl8rYdDID/view?usp=sharing) dans la session

# %%
from module_tree import Node,Arbre 
from module_tree import addNodes,make_it

# %%
# voir la doc du module complète
help(Arbre)

# %% [markdown]
# <font color=lightseagreen size=6><b>Création de l'arbre</b></font>
#
# Le module **module_tree** contient une fonction addNodes, mais elle est incomplète..
#
# Ci dessous, on crée un Arbre dont la racine porte l'étiquette "04" et on ajoute les noeuds avec addNodes
#
# Regardez le dessin de l'arbre obtenu et comparez avec le votre (fait à la main) pour déterminer les noeuds manquants.
#
# Ensuite, ajoutez les instructions qui permettent d'ajouter ces noeuds.

# %%
arbre=Arbre("04")
addNodes(arbre)
### après avoir vu l'arbre construit ci-dessus, ajoutez les instructions ci-dessous ###

# puis refaire le dessin
arbre.show()

# %%
# test de votre arbre
from module_tree import test_arbre
test_arbre(arbre)

# %% [markdown]
# En principe arbre contient maintenant (et jusqu'à la fin du TP) l'Arbre correct. Si toutefois une fausse manipulation le détruisait, vous pouvez le reconstruire avec la cellule ci-dessous :

# %%
from module_tree import make_it
arbre = make_it()
test_arbre(arbre)

# %% [markdown]
# <b><font color="lightseagreen" size="6">Les parcours en profondeur</font></b>
#
# Que fait le code ci-dessous ?

# %%
def mystere(arbre):

    print(arbre.etiquette_racine,end=" -> ")

    if arbre.racine().fg is not None :  
        mystere(arbre.sag())

    if arbre.racine().fd is not None :  
        mystere(arbre.sad())

mystere(arbre)

# %% [markdown]
# <b><font color="lightseagreen" size="5">A faire vous même 1</font></b>
#
# Modifiez le code pour qu'il renvoie la liste des sommets visités (au lieu d'afficher)

# %%
def parcours_prefixe(arbre):
    """ ajoutez une docstring """

    visites = [arbre.etiquette_racine]

    if arbre.racine().fg is not None :  
        visites += parcours_prefixe(arbre.sag())

    if arbre.racine().fd is not None :  
        visites += parcours_prefixe(arbre.sad())  
    return visites

# %%
prefixe = parcours_prefixe(arbre)
print(prefixe)
# l'appel de show avec une liste permet d'afficher en vert les noeud présents dans la liste
# vérifions que nous avons tout visité :
arbre.show(verts = prefixe)

# %% [markdown]
# <b><font color="lightseagreen" size="5">A faire vous même 2</font></b>
#
# Faire de même pour un parcours sufixe

# %%
def parcours_sufixe(arbre):
    """ ajoutez une docstring """

    visites = []
    if arbre.racine().fg is not None :  
        visites += parcours_sufixe(arbre.sag())

    if arbre.racine().fd is not None :  
        visites += parcours_sufixe(arbre.sad())  

    visites += [arbre.etiquette_racine]

    return visites

# %%
sufixe = parcours_sufixe( arbre)
print(chemin)
# vérifiez si tous les noeuds ont été visités :
arbre.show(verts = sufixe)

# %% [markdown]
# <b><font color="lightseagreen" size="5">A faire vous même 3</font></b>
#
# Faire de même pour un parcours infixe

# %%
def parcours_infixe(arbre):
    """ ajoutez une docstring """
    visites = []
    if arbre.racine().fg is not None : 
        visites += parcours_infixe(arbre.sag())

    visites += [arbre.etiquette_racine]

    if arbre.racine().fd is not None :  
        visites += parcours_infixe(arbre.sad())  

    return visites

# %%
infixe = parcours_infixe( arbre)
print(chemin)
# vérifiez si tous les noeuds ont été visités :
arbre.show(verts = infixe)

# %% [markdown]
# <b><font color="lightseagreen" size="5">Une autre écriture plus concise</font></b>

# %%
def prefixe(arbre) :
  if arbre.empty():
      return []
  else :
      return [arbre.etiquette_racine] + prefixe(arbre.sag())  +  prefixe(arbre.sad())

# %%
print(prefixe(arbre))
# Out:
# ['04', '14', '24', '23', '22', '12', '13', '03', '02', '32', '31', '21', '11', '10', '00', '01', '20', '30', '40', '41', '33', '34', '44', '43', '42', '52', '51', '53', '54']

# %% [markdown]
# <b><font color="lightseagreen" size="5">A faire vous même 4</font></b>
#
# Faire de même pour un parcours sufixe et un parcours infixe

# %%
def sufixe(arbre) :
  if arbre.empty():
      return []
  else :
      return sufixe(arbre.sag())  +  sufixe(arbre.sad())  + [arbre.etiquette_racine]  
print(sufixe(arbre))
# Out:
# ['02', '03', '13', '12', '01', '00', '10', '11', '40', '30', '20', '21', '41', '31', '32', '22', '33', '23', '51', '54', '53', '52', '42', '43', '44', '34', '24', '14', '04']

# %%
def infixe(arbre) :
  if arbre.empty():
      return []
  else :
      return  infixe(arbre.sag()) + [arbre.etiquette_racine] +  infixe(arbre.sad()) 
print(infixe(arbre))
# Out:
# ['02', '03', '13', '12', '22', '01', '00', '10', '11', '21', '40', '30', '20', '31', '41', '32', '23', '33', '24', '51', '52', '54', '53', '42', '43', '44', '34', '14', '04']

# %% [markdown]
# <b><font color="lightseagreen" size="5">A faire vous même 5</font></b>
#
# Ecrire une fonction récursive `getFeuilles(noeud)` qui renvoie la liste des culs de sac du labyrinthe (la sortie est comptée comme un cul de sac) issue de ce noeud.

# %%
def getFeuilles(arbre):

    """ ajoutez une docsting """
    
    feuilles = []
    if arbre.racine().fg is not None : 
        feuilles += getFeuilles(arbre.sag())

    if arbre.racine().fd is not None :  
        feuilles += getFeuilles(arbre.sad())  

    if arbre.est_feuille(arbre.etiquette_racine) :
        feuilles += [arbre.etiquette_racine]

    return feuilles

feuilles = getFeuilles( arbre)
print(feuilles)
# vérifiez si les feuilles sont vertes :
arbre.show(verts = feuilles)

# %% [markdown]
# <center>
#
# ---
#
# **Auteur** Jean-Louis Thirot - Lycée Bertrand d'Argentré - Vitré (35)
#
# Publié sous licence CC BY-NC-SA
#
#
# ---
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" width="200" src="https://s2.qwant.com/thumbr/700x0/f/9/436dcce5e02185c0b2e1b0e7a969aa81d7b0438d0a7f2eaee89abb9661b70b/cc-by-nc-sa.svg_.png?u=http%3A%2F%2Fopensiddur.org%2Fwp-content%2Fuploads%2F2011%2F03%2Fcc-by-nc-sa.svg_.png&q=0&b=1&p=0&a=1" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
